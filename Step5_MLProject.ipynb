# %%
# !git clone https://github.com/matteogirellipolito/ML_Project
# %cd ML_Project/eomt
# !git pull
# Out:
# Cloning into 'ML_Project'...
# remote: Enumerating objects: 578, done.
# remote: Counting objects: 100% (64/64), done.
# remote: Compressing objects: 100% (23/23), done.
# remote: Total 578 (delta 54), reused 47 (delta 41), pack-reused 514 (from 3)
# Receiving objects: 100% (578/578), 27.00 MiB | 13.73 MiB/s, done.
# Resolving deltas: 100% (234/234), done.
# /content/ML_Project/eomt
# Already up to date.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install ood_metrics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 3.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 101.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# jaxlib 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# opencv-python 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# tobler 0.14.0 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# tifffile 2026.4.11 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# cupy-cuda12x 14.0.1 requires numpy<2.6,>=2.0, but you have numpy 1.26.4 which is incompatible.
# ...

# %%
# !pip install lightning
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 3.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 848.6/848.6 kB 28.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 983.4/983.4 kB 34.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 852.4/852.4 kB 32.2 MB/s eta 0:00:00
# ...

# %%
# !python evalAnomaly_eomt.py --input "/content/drive/MyDrive/Anomaly_Validation_Datasets/Validation_Dataset/RoadAnomaly/images/*.jpg"
# !python evalAnomaly_eomt.py --input "/content/drive/MyDrive/Anomaly_Validation_Datasets/Validation_Dataset/RoadAnomaly21/images/*.png"
# !python evalAnomaly_eomt.py --input "/content/drive/MyDrive/Anomaly_Validation_Datasets/Validation_Dataset/RoadObsticle21/images/*.webp"
# !python evalAnomaly_eomt.py --input "/content/drive/MyDrive/Anomaly_Validation_Datasets/Validation_Dataset/fs_static/images/*.jpg"
# Out:
# model.safetensors: 100% 346M/346M [00:02<00:00, 137MB/s]
# /usr/local/lib/python3.12/dist-packages/lightning/pytorch/utilities/parsing.py:213: Attribute 'network' is an instance of `nn.Module` and is already saved during checkpointing. It is recommended to ignore them using `self.save_hyperparameters(ignore=['network'])`.
# Model weights loaded succesfully
#
# Running method: MSP
#
# /content/drive/MyDrive/Anomaly_Validation_Datasets/Validation_Dataset/RoadAnomaly21/images/5.png
# /content/drive/MyDrive/Anomaly_Validation_Datasets/Validation_Dataset/RoadAnomaly21/images/9.png
# /content/drive/MyDrive/Anomaly_Validation_Datasets/Validation_Dataset/RoadAnomaly21/images/6.png
# /content/drive/MyDrive/Anomaly_Validation_Datasets/Validation_Dataset/RoadAnomaly21/images/3.png
# /content/drive/MyDrive/Anomaly_Validation_Datasets/Validation_Dataset/RoadAnomaly21/images/1.png
# /content/drive/MyDrive/Anomaly_Validation_Datasets/Validation_Dataset/RoadAnomaly21/images/4.png
# ...

# %%
# !python evalAnomaly_eomt.py --input "/content/drive/MyDrive/Anomaly_Validation_Datasets/Validation_Dataset/FS_LostFound_full/images/*.png"
# Out:
# ...
# /usr/local/lib/python3.12/dist-packages/lightning/pytorch/utilities/parsing.py:213: Attribute 'network' is an instance of `nn.Module` and is already saved during checkpointing. It is recommended to ignore them using `self.save_hyperparameters(ignore=['network'])`.
# Model weights loaded succesfully
#
# Running method: MSP
#
# /content/drive/MyDrive/Anomaly_Validation_Datasets/Validation_Dataset/FS_LostFound_full/images/88.png
# /content/drive/MyDrive/Anomaly_Validation_Datasets/Validation_Dataset/FS_LostFound_full/images/48.png
# /content/drive/MyDrive/Anomaly_Validation_Datasets/Validation_Dataset/FS_LostFound_full/images/72.png
# /content/drive/MyDrive/Anomaly_Validation_Datasets/Validation_Dataset/FS_LostFound_full/images/8.png
# /content/drive/MyDrive/Anomaly_Validation_Datasets/Validation_Dataset/FS_LostFound_full/images/58.png
# /content/drive/MyDrive/Anomaly_Validation_Datasets/Validation_Dataset/FS_LostFound_full/images/63.png
# ...

# %% [markdown]
# Calcolo mIoU per EoMT

# %%
# !pip install cityscapesscripts

import os
os.environ['CITYSCAPES_DATASET'] = '/content/drive/MyDrive/Anomaly_Validation_Datasets/Cityscapes'

# !python -m cityscapesscripts.preparation.createTrainIdLabelImgs
# Out:
# ...
# Processing 500 annotation files
# Progress: 100.0 %

# %%
# !python eval_iou_eomt.py
# Out:
# /usr/local/lib/python3.12/dist-packages/lightning/pytorch/utilities/parsing.py:213: Attribute 'network' is an instance of `nn.Module` and is already saved during checkpointing. It is recommended to ignore them using `self.save_hyperparameters(ignore=['network'])`.
# Model weights loaded succesfully
# /content/drive/MyDrive/Anomaly_Validation_Datasets/Cityscapes_val/leftImg8bit/val /content/drive/MyDrive/Anomaly_Validation_Datasets/Cityscapes_val/gtFine/val
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:424: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   self.check_worker_number_rationality()
# ...

# %% [markdown]
# Temperature Scaling

# %%
# !python eomtTemperatureScaling.py --input "/content/drive/MyDrive/Anomaly_Validation_Datasets/Validation_Dataset/RoadAnomaly/images/*.jpg" \
  --temperature  1 80 120 180
# Out:
# /usr/local/lib/python3.12/dist-packages/lightning/pytorch/utilities/parsing.py:213: Attribute 'network' is an instance of `nn.Module` and is already saved during checkpointing. It is recommended to ignore them using `self.save_hyperparameters(ignore=['network'])`.
# Model weights loaded succesfully
# /content/drive/MyDrive/Anomaly_Validation_Datasets/Validation_Dataset/RoadAnomaly/images/49.jpg
# /content/drive/MyDrive/Anomaly_Validation_Datasets/Validation_Dataset/RoadAnomaly/images/48.jpg
# /content/drive/MyDrive/Anomaly_Validation_Datasets/Validation_Dataset/RoadAnomaly/images/58.jpg
# /content/drive/MyDrive/Anomaly_Validation_Datasets/Validation_Dataset/RoadAnomaly/images/59.jpg
# /content/drive/MyDrive/Anomaly_Validation_Datasets/Validation_Dataset/RoadAnomaly/images/56.jpg
# /content/drive/MyDrive/Anomaly_Validation_Datasets/Validation_Dataset/RoadAnomaly/images/33.jpg
# /content/drive/MyDrive/Anomaly_Validation_Datasets/Validation_Dataset/RoadAnomaly/images/38.jpg
# ...

# %%
# !python eomtTemperatureScaling.py --input "/content/drive/MyDrive/Anomaly_Validation_Datasets/Validation_Dataset/RoadAnomaly21/images/*.png"\
  --temperature 1 140 180
# Out:
# /usr/local/lib/python3.12/dist-packages/lightning/pytorch/utilities/parsing.py:213: Attribute 'network' is an instance of `nn.Module` and is already saved during checkpointing. It is recommended to ignore them using `self.save_hyperparameters(ignore=['network'])`.
# Model weights loaded succesfully
# /content/drive/MyDrive/Anomaly_Validation_Datasets/Validation_Dataset/RoadAnomaly21/images/5.png
# /content/drive/MyDrive/Anomaly_Validation_Datasets/Validation_Dataset/RoadAnomaly21/images/9.png
# /content/drive/MyDrive/Anomaly_Validation_Datasets/Validation_Dataset/RoadAnomaly21/images/6.png
# /content/drive/MyDrive/Anomaly_Validation_Datasets/Validation_Dataset/RoadAnomaly21/images/3.png
# /content/drive/MyDrive/Anomaly_Validation_Datasets/Validation_Dataset/RoadAnomaly21/images/1.png
# /content/drive/MyDrive/Anomaly_Validation_Datasets/Validation_Dataset/RoadAnomaly21/images/4.png
# /content/drive/MyDrive/Anomaly_Validation_Datasets/Validation_Dataset/RoadAnomaly21/images/7.png
# ...

# %%
# !python eomtTemperatureScaling.py --input "/content/drive/MyDrive/Anomaly_Validation_Datasets/Validation_Dataset/RoadObsticle21/images/*.webp" \
  --temperature 1 20 22 23 24 25 30
# Out:
# ...
# /usr/local/lib/python3.12/dist-packages/lightning/pytorch/utilities/parsing.py:213: Attribute 'network' is an instance of `nn.Module` and is already saved during checkpointing. It is recommended to ignore them using `self.save_hyperparameters(ignore=['network'])`.
# Model weights loaded succesfully
# /content/drive/MyDrive/Anomaly_Validation_Datasets/Validation_Dataset/RoadObsticle21/images/25.webp
# /content/drive/MyDrive/Anomaly_Validation_Datasets/Validation_Dataset/RoadObsticle21/images/9.webp
# /content/drive/MyDrive/Anomaly_Validation_Datasets/Validation_Dataset/RoadObsticle21/images/15.webp
# /content/drive/MyDrive/Anomaly_Validation_Datasets/Validation_Dataset/RoadObsticle21/images/18.webp
# /content/drive/MyDrive/Anomaly_Validation_Datasets/Validation_Dataset/RoadObsticle21/images/29.webp
# /content/drive/MyDrive/Anomaly_Validation_Datasets/Validation_Dataset/RoadObsticle21/images/13.webp
# ...

# %%
# !python eomtTemperatureScaling.py --input "/content/drive/MyDrive/Anomaly_Validation_Datasets/Validation_Dataset/fs_static/images/*.jpg" \
  --temperature 1 2 3 4 5 5.25 5.5 5.75 6 6.25 6.5 7 8 9 10
# Out:
# /usr/local/lib/python3.12/dist-packages/lightning/pytorch/utilities/parsing.py:213: Attribute 'network' is an instance of `nn.Module` and is already saved during checkpointing. It is recommended to ignore them using `self.save_hyperparameters(ignore=['network'])`.
# Model weights loaded succesfully
# /content/drive/MyDrive/Anomaly_Validation_Datasets/Validation_Dataset/fs_static/images/17.jpg
# /content/drive/MyDrive/Anomaly_Validation_Datasets/Validation_Dataset/fs_static/images/12.jpg
# /content/drive/MyDrive/Anomaly_Validation_Datasets/Validation_Dataset/fs_static/images/16.jpg
# /content/drive/MyDrive/Anomaly_Validation_Datasets/Validation_Dataset/fs_static/images/14.jpg
# /content/drive/MyDrive/Anomaly_Validation_Datasets/Validation_Dataset/fs_static/images/15.jpg
# /content/drive/MyDrive/Anomaly_Validation_Datasets/Validation_Dataset/fs_static/images/29.jpg
# /content/drive/MyDrive/Anomaly_Validation_Datasets/Validation_Dataset/fs_static/images/28.jpg
# ...

# %% [markdown]
# Per FS_LostFound utilizzare poche temperature

# %%
# !python eomtTemperatureScaling.py --input "/content/drive/MyDrive/Anomaly_Validation_Datasets/Validation_Dataset/FS_LostFound_full/images/*.png" \
  --temperature 1 10
# Out:
# ...
# model.safetensors: 100% 346M/346M [00:02<00:00, 122MB/s]
# /usr/local/lib/python3.12/dist-packages/lightning/pytorch/utilities/parsing.py:213: Attribute 'network' is an instance of `nn.Module` and is already saved during checkpointing. It is recommended to ignore them using `self.save_hyperparameters(ignore=['network'])`.
# Model weights loaded succesfully
# /content/drive/MyDrive/Anomaly_Validation_Datasets/Validation_Dataset/FS_LostFound_full/images/88.png
# /content/drive/MyDrive/Anomaly_Validation_Datasets/Validation_Dataset/FS_LostFound_full/images/48.png
# /content/drive/MyDrive/Anomaly_Validation_Datasets/Validation_Dataset/FS_LostFound_full/images/72.png
# /content/drive/MyDrive/Anomaly_Validation_Datasets/Validation_Dataset/FS_LostFound_full/images/8.png
# /content/drive/MyDrive/Anomaly_Validation_Datasets/Validation_Dataset/FS_LostFound_full/images/58.png
# /content/drive/MyDrive/Anomaly_Validation_Datasets/Validation_Dataset/FS_LostFound_full/images/63.png
# ...

# %%
# !python eomtTemperatureScaling.py --input "/content/drive/MyDrive/Anomaly_Validation_Datasets/Validation_Dataset/FS_LostFound_full/images/*.png" \
  --temperature 20 30
# Out:
# ...
# /usr/local/lib/python3.12/dist-packages/lightning/pytorch/utilities/parsing.py:213: Attribute 'network' is an instance of `nn.Module` and is already saved during checkpointing. It is recommended to ignore them using `self.save_hyperparameters(ignore=['network'])`.
# Model weights loaded succesfully
# /content/drive/MyDrive/Anomaly_Validation_Datasets/Validation_Dataset/FS_LostFound_full/images/88.png
# /content/drive/MyDrive/Anomaly_Validation_Datasets/Validation_Dataset/FS_LostFound_full/images/48.png
# /content/drive/MyDrive/Anomaly_Validation_Datasets/Validation_Dataset/FS_LostFound_full/images/72.png
# /content/drive/MyDrive/Anomaly_Validation_Datasets/Validation_Dataset/FS_LostFound_full/images/8.png
# /content/drive/MyDrive/Anomaly_Validation_Datasets/Validation_Dataset/FS_LostFound_full/images/58.png
# /content/drive/MyDrive/Anomaly_Validation_Datasets/Validation_Dataset/FS_LostFound_full/images/63.png
# ...

# %%
# !python eomtTemperatureScaling.py --input "/content/drive/MyDrive/Anomaly_Validation_Datasets/Validation_Dataset/FS_LostFound_full/images/*.png" \
  --temperature 40 50
# Out:
# /usr/local/lib/python3.12/dist-packages/lightning/pytorch/utilities/parsing.py:213: Attribute 'network' is an instance of `nn.Module` and is already saved during checkpointing. It is recommended to ignore them using `self.save_hyperparameters(ignore=['network'])`.
# Model weights loaded succesfully
# /content/drive/MyDrive/Anomaly_Validation_Datasets/Validation_Dataset/FS_LostFound_full/images/88.png
# /content/drive/MyDrive/Anomaly_Validation_Datasets/Validation_Dataset/FS_LostFound_full/images/48.png
# /content/drive/MyDrive/Anomaly_Validation_Datasets/Validation_Dataset/FS_LostFound_full/images/72.png
# /content/drive/MyDrive/Anomaly_Validation_Datasets/Validation_Dataset/FS_LostFound_full/images/8.png
# /content/drive/MyDrive/Anomaly_Validation_Datasets/Validation_Dataset/FS_LostFound_full/images/58.png
# /content/drive/MyDrive/Anomaly_Validation_Datasets/Validation_Dataset/FS_LostFound_full/images/63.png
# ...
